# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')

# Add working directory from google drive
FOLDERNAME = 'CS6220/HW7'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Specify the working directory
work_path = '/content/drive/My Drive/{}'.format(FOLDERNAME)

# Add to the system
import sys
sys.path.append(work_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv(os.path.join(work_path, "titanic.train.csv"))
test_data = pd.read_csv(os.path.join(work_path, "titanic.test.csv"))

# %%
train_data.shape
# Out:
# (891, 14)

# %%
train_data.head()
# Out:
#    pclass  survived                                    name     sex   age  \
# 0       3         1             Sheerlinck, Mr. Jan Baptist    male  29.0
# 1       2         1              Quick, Miss. Winifred Vera  female   8.0
# 2       1         1       Pears, Mrs. Thomas (Edith Wearne)  female  22.0
# 3       1         0            Crosby, Capt. Edward Gifford    male  70.0
# 4       3         1  Daly, Miss. Margaret Marcella "Maggie"  female  30.0
#
#    sibsp  parch     ticket   fare cabin embarked boat   body  \
# 0      0      0     345779   9.50   NaN        S   11    NaN
# 1      1      1      26360  26.00   NaN        S   11    NaN
# 2      1      0     113776  66.60    C2        S    8    NaN
# 3      1      1  WE/P 5735  71.00   B22        S  NaN  269.0
# 4      0      0     382650   6.95   NaN        Q   15    NaN
#
#                           home.dest
# 0                               NaN
# 1     Plymouth, Devon / Detroit, MI
# 2                Isleworth, England
# 3                     Milwaukee, WI
# 4  Co Athlone, Ireland New York, NY

# %%
test_data.shape
# Out:
# (418, 13)

# %%
test_data.head()
# Out:
#    Unnamed: 0  pclass  survived                                         name  \
# 0           0       3         0            Sage, Miss. Dorothy Edith "Dolly"
# 1           1       3         0                  Alhomaki, Mr. Ilmari Rudolf
# 2           2       3         0                       Alexander, Mr. William
# 3           3       1         1              Schabert, Mrs. Paul (Emma Mock)
# 4           4       1         0  Rosenshine, Mr. George ("Mr George Thorne")
#
#       sex   age  sibsp  parch            ticket     fare cabin embarked  \
# 0  female   NaN      8      2          CA. 2343  69.5500   NaN        S
# 1    male  20.0      0      0  SOTON/O2 3101287   7.9250   NaN        S
# 2    male  26.0      0      0              3474   7.8875   NaN        S
# 3  female  35.0      1      0             13236  57.7500   C28        C
# 4    male  46.0      0      0          PC 17585  79.2000   NaN        C
#
#                    home.dest
# 0                        NaN
# 1  Salo, Finland Astoria, OR
# 2         England Albion, NY
# 3               New York, NY
# 4               New York, NY

# %%
# remove the first column
test_data = test_data.iloc[:,1:]

# %%
test_data.head()
# Out:
#    pclass  survived                                         name     sex  \
# 0       3         0            Sage, Miss. Dorothy Edith "Dolly"  female
# 1       3         0                  Alhomaki, Mr. Ilmari Rudolf    male
# 2       3         0                       Alexander, Mr. William    male
# 3       1         1              Schabert, Mrs. Paul (Emma Mock)  female
# 4       1         0  Rosenshine, Mr. George ("Mr George Thorne")    male
#
#     age  sibsp  parch            ticket     fare cabin embarked  \
# 0   NaN      8      2          CA. 2343  69.5500   NaN        S
# 1  20.0      0      0  SOTON/O2 3101287   7.9250   NaN        S
# 2  26.0      0      0              3474   7.8875   NaN        S
# 3  35.0      1      0             13236  57.7500   C28        C
# 4  46.0      0      0          PC 17585  79.2000   NaN        C
#
#                    home.dest
# 0                        NaN
# 1  Salo, Finland Astoria, OR
# 2         England Albion, NY
# 3               New York, NY
# 4               New York, NY

# %% [markdown]
# ## EDA

# %%
train_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
test_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'home.dest'],
#       dtype='object')

# %% [markdown]
# There are more columns in the training set, we need to match the column from training and test set by selecting a subset of common columns. For this reason, we will not use boat and body column.
#
# Besides these two columns, we're also not going to use name column because it's not beneficial for the prediction.

# %%
train_data
# Out:
#      pclass  survived                                               name  \
# 0         3         1                        Sheerlinck, Mr. Jan Baptist
# 1         2         1                         Quick, Miss. Winifred Vera
# 2         1         1                  Pears, Mrs. Thomas (Edith Wearne)
# 3         1         0                       Crosby, Capt. Edward Gifford
# 4         3         1             Daly, Miss. Margaret Marcella "Maggie"
# ..      ...       ...                                                ...
# 886       1         0                         Hays, Mr. Charles Melville
# 887       3         1  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 888       3         0                                      Ling, Mr. Lee
# 889       3         0                       Saether, Mr. Simon Sivertsen
# 890       1         0                                Ringhini, Mr. Sante
#
#         sex   age  sibsp  parch              ticket      fare cabin embarked  \
# 0      male  29.0      0      0              345779    9.5000   NaN        S
# 1    female   8.0      1      1               26360   26.0000   NaN        S
# 2    female  22.0      1      0              113776   66.6000    C2        S
# 3      male  70.0      1      1           WE/P 5735   71.0000   B22        S
# 4    female  30.0      0      0              382650    6.9500   NaN        Q
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 886    male  55.0      1      1               12749   93.5000   B69        S
# 887  female  24.0      1      0    STON/O2. 3101279   15.8500   NaN        S
# 888    male  28.0      0      0                1601   56.4958   NaN        S
# 889    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 890    male  22.0      0      0            PC 17760  135.6333   NaN        C
#
#     boat   body                         home.dest
# 0     11    NaN                               NaN
# 1     11    NaN     Plymouth, Devon / Detroit, MI
# 2      8    NaN                Isleworth, England
# 3    NaN  269.0                     Milwaukee, WI
# 4     15    NaN  Co Athlone, Ireland New York, NY
# ..   ...    ...                               ...
# 886  NaN  307.0                      Montreal, PQ
# 887   15    NaN                               NaN
# 888  NaN    NaN                               NaN
# 889  NaN   32.0                               NaN
# 890  NaN  232.0                               NaN
#
# [891 rows x 14 columns]

# %% [markdown]
# ### Survived

# %%
train_data["survived"].value_counts()
# Out:
# 0    536
# 1    355
# Name: survived, dtype: int64

# %%
survival_rate = train_data["survived"].value_counts() / train_data.shape[0]
survival_rate
# Out:
# 0    0.601571
# 1    0.398429
# Name: survived, dtype: float64

# %% [markdown]
# A bit unbalanced but still ok

# %% [markdown]
# ### PClass

# %%
train_data["pclass"].isna().sum()
# Out:
# 0

# %%
train_data["pclass"].value_counts()
# Out:
# 3    490
# 1    212
# 2    189
# Name: pclass, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="pclass", hue="survived", data=train_data)
plt.title(f'pclass vs survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# From the plot, we can see the clearly the relationship between pclass and survived variables. Lower pclass has a higher chance of surviving. This indicates that pclass is a good predictor.

# %% [markdown]
# ### sex

# %%
train_data["sex"].isna().sum()
# Out:
# 0

# %%
train_data["sex"].value_counts()
# Out:
# male      575
# female    316
# Name: sex, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="sex", hue="survived", data=train_data)
plt.title(f'sex vs survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# There is a strong correlation between gender and survived variables. Female is generally has more chance to survive compared to male.

# %% [markdown]
# ### age

# %%
train_data["age"].isna().sum()
# Out:
# 193

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.histplot(x="age", hue="survived", data=train_data, ax=ax, alpha=0.5)
plt.title(f'Distribution of age')
plt.ylabel('Age')
plt.show()

# %%
age_threshold = 18

# %%
train_data[train_data["age"] < age_threshold]["survived"].value_counts()
# Out:
# 1    57
# 0    47
# Name: survived, dtype: int64

# %%
train_data[train_data["age"] >= age_threshold]["survived"].value_counts()
# Out:
# 0    351
# 1    243
# Name: survived, dtype: int64

# %% [markdown]
# From here, we can see that the age under 18 is more likely to survive, we can add one indicator variable indicating whether or not the passenger is above 18.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="survived", y="age", data=train_data)
plt.title(f'age vs survived')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# There is not much correlation between age and survived variables.

# %%
missing_age = train_data[train_data["age"].isna()]
not_missing_age = train_data[~train_data["age"].isna()]

# %%
survival_rate_missing_age = missing_age["survived"].value_counts() / missing_age.shape[0]
survival_rate_non_missing_age = not_missing_age["survived"].value_counts() / not_missing_age.shape[0]

# %%
survival_rate_missing_age
# Out:
# 0    0.715026
# 1    0.284974
# Name: survived, dtype: float64

# %%
survival_rate_non_missing_age
# Out:
# 0    0.570201
# 1    0.429799
# Name: survived, dtype: float64

# %% [markdown]
# Seems like the missing age value contain a bit of information to the survival. We're going to impute the missing age using the mean and add new indicator variable that the age is missing.

# %% [markdown]
# ### Number of siblings / spouse aboard

# %%
train_data["sibsp"].value_counts()
# Out:
# 0    608
# 1    221
# 2     22
# 4     16
# 3     13
# 8      6
# 5      5
# Name: sibsp, dtype: int64

# %%
train_data["sibsp"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="sibsp", hue="survived", data=train_data)
plt.title(f'Number of siblings / spouse vs survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Number of parents / childern aboard

# %%
train_data["parch"].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="parch", hue="survived", data=train_data)
plt.title(f'Number of parents / children vs survived')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="parch", hue="survived", data=train_data[train_data["parch"] > 2])
plt.title(f'Number of parents / children vs survived > 2')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Ticket

# %%
train_data["ticket"].head(10)
# Out:
# 0                345779
# 1                 26360
# 2                113776
# 3             WE/P 5735
# 4                382650
# 5    SOTON/O.Q. 3101314
# 6           S.O./P.P. 2
# 7            C.A. 33111
# 8               3101295
# 9             Fa 265302
# Name: ticket, dtype: object

# %%
train_data[train_data["ticket"] == "113776"]
# Out:
#      pclass  survived                               name     sex   age  sibsp  \
# 2         1         1  Pears, Mrs. Thomas (Edith Wearne)  female  22.0      1
# 734       1         0          Pears, Mr. Thomas Clinton    male  29.0      1
#
#      parch  ticket  fare cabin embarked boat  body           home.dest
# 2        0  113776  66.6    C2        S    8   NaN  Isleworth, England
# 734      0  113776  66.6    C2        S  NaN   NaN  Isleworth, England

# %%
train_data[train_data["ticket"] == "SOTON/O.Q. 3101314"]
# Out:
#    pclass  survived                                    name   sex  age  sibsp  \
# 5       3         0  Franklin, Mr. Charles (Charles Fardon)  male  NaN      0
#
#    parch              ticket  fare cabin embarked boat  body home.dest
# 5      0  SOTON/O.Q. 3101314  7.25   NaN        S  NaN   NaN       NaN

# %% [markdown]
# At first glance column ticket doesn't seem to be meaningful.

# %%
vc = train_data["ticket"].value_counts()
vc[vc > 1]
# Out:
# CA 2144         7
# CA. 2343        7
# 1601            6
# 347082          6
# PC 17608        5
#                ..
# F.C.C. 13529    2
# 226875          2
# 29103           2
# 19996           2
# 113796          2
# Name: ticket, Length: 117, dtype: int64

# %%
train_data[train_data["ticket"] == "CA 2144"]
# Out:
#      pclass  survived                                     name     sex   age  \
# 71        3         0  Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0
# 98        3         0           Goodwin, Mr. Charles Frederick    male  40.0
# 279       3         0          Goodwin, Master. Sidney Leonard    male   1.0
# 439       3         0              Goodwin, Miss. Jessie Allis  female  10.0
# 490       3         0       Goodwin, Master. William Frederick    male  11.0
# 835       3         0              Goodwin, Mr. Charles Edward    male  14.0
# 861       3         0               Goodwin, Miss. Lillian Amy  female  16.0
#
#      sibsp  parch   ticket  fare cabin embarked boat  body  \
# 71       1      6  CA 2144  46.9   NaN        S  NaN   NaN
# 98       1      6  CA 2144  46.9   NaN        S  NaN   NaN
# 279      5      2  CA 2144  46.9   NaN        S  NaN   NaN
# 439      5      2  CA 2144  46.9   NaN        S  NaN   NaN
# 490      5      2  CA 2144  46.9   NaN        S  NaN   NaN
# 835      5      2  CA 2144  46.9   NaN        S  NaN   NaN
# 861      5      2  CA 2144  46.9   NaN        S  NaN   NaN
#
#                                 home.dest
# 71   Wiltshire, England Niagara Falls, NY
# 98   Wiltshire, England Niagara Falls, NY
# 279  Wiltshire, England Niagara Falls, NY
# 439  Wiltshire, England Niagara Falls, NY
# 490  Wiltshire, England Niagara Falls, NY
# 835  Wiltshire, England Niagara Falls, NY
# 861  Wiltshire, England Niagara Falls, NY

# %%
train_data[train_data["ticket"] == "PC 17608"]
# Out:
#      pclass  survived                                             name  \
# 277       1         1                      Ryerson, Master. John Borie
# 480       1         1            Ryerson, Miss. Susan Parker "Suzette"
# 486       1         1  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 661       1         1                         Bowen, Miss. Grace Scott
# 748       1         1                      Chaudanson, Miss. Victorine
#
#         sex   age  sibsp  parch    ticket     fare            cabin embarked  \
# 277    male  13.0      2      2  PC 17608  262.375  B57 B59 B63 B66        C
# 480  female  21.0      2      2  PC 17608  262.375  B57 B59 B63 B66        C
# 486  female  48.0      1      3  PC 17608  262.375  B57 B59 B63 B66        C
# 661  female  45.0      0      0  PC 17608  262.375              NaN        C
# 748  female  36.0      0      0  PC 17608  262.375              B61        C
#
#     boat  body                        home.dest
# 277    4   NaN  Haverford, PA / Cooperstown, NY
# 480    4   NaN  Haverford, PA / Cooperstown, NY
# 486    4   NaN  Haverford, PA / Cooperstown, NY
# 661    4   NaN                  Cooperstown, NY
# 748    4   NaN                              NaN

# %% [markdown]
# Based on this result, we decided to not use the ticket

# %% [markdown]
# ### Fare

# %%
train_data["fare"].isna().sum()
# Out:
# 1

# %%
train_data[train_data["fare"].isna()]
# Out:
#      pclass  survived                name   sex   age  sibsp  parch ticket  \
# 521       3         0  Storey, Mr. Thomas  male  60.5      0      0   3701
#
#      fare cabin embarked boat   body home.dest
# 521   NaN   NaN        S  NaN  261.0       NaN

# %% [markdown]
# Since the distribution of fare is heavy on the right tail, we decided to impute the fare using median

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.histplot(x="fare", hue="survived", data=train_data, ax=ax, alpha=0.5)
plt.title(f'Distribution of fare')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# Seems like fare has strong correlation with the survival of passenger. Let's zoom in

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
sns.histplot(x="fare", hue="survived", data=train_data[train_data["fare"] > 70], ax=ax, alpha=0.5)
plt.title(f'Distribution of fare')
plt.ylabel('Fare')
plt.show()

# %%
train_data["fare>70"] = train_data["fare"] > 70

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="fare>70", hue="survived", data=train_data)
plt.title(f'Fare vs survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Cabin

# %%
train_data["cabin"].value_counts()
# Out:
# G6             4
# F4             4
# B58 B60        3
# C78            3
# B96 B98        3
#               ..
# C106           1
# E31            1
# C110           1
# B51 B53 B55    1
# E60            1
# Name: cabin, Length: 142, dtype: int64

# %%
train_data["cabin"].isna().sum()
# Out:
# 702

# %%
train_data[train_data["cabin"] == "G6"]
# Out:
#      pclass  survived                                               name  \
# 196       3         0         Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 620       3         1  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...
# 719       3         1                    Sandstrom, Miss. Marguerite Rut
# 882       3         0                         Strom, Miss. Telma Matilda
#
#         sex   age  sibsp  parch   ticket     fare cabin embarked boat  body  \
# 196  female  29.0      1      1   347054  10.4625    G6        S  NaN   NaN
# 620  female  24.0      0      2  PP 9549  16.7000    G6        S   13   NaN
# 719  female   4.0      1      1  PP 9549  16.7000    G6        S   13   NaN
# 882  female   2.0      0      1   347054  10.4625    G6        S  NaN   NaN
#
#     home.dest  fare>70
# 196       NaN    False
# 620       NaN    False
# 719       NaN    False
# 882       NaN    False

# %%
train_data[train_data["cabin"] == "F4"]
# Out:
#      pclass  survived                                              name  \
# 40        2         1                       Becker, Miss. Marion Louise
# 327       2         1                      Becker, Miss. Ruth Elizabeth
# 660       2         1  Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 870       2         1                         Becker, Master. Richard F
#
#         sex   age  sibsp  parch  ticket  fare cabin embarked boat  body  \
# 40   female   4.0      2      1  230136  39.0    F4        S   11   NaN
# 327  female  12.0      2      1  230136  39.0    F4        S   13   NaN
# 660  female  36.0      0      3  230136  39.0    F4        S   11   NaN
# 870    male   1.0      2      1  230136  39.0    F4        S   11   NaN
#
#                               home.dest  fare>70
# 40   Guntur, India / Benton Harbour, MI    False
# 327  Guntur, India / Benton Harbour, MI    False
# 660  Guntur, India / Benton Harbour, MI    False
# 870  Guntur, India / Benton Harbour, MI    False

# %%
train_data[train_data["cabin"] == "B96 B98"]
# Out:
#      pclass  survived                                       name     sex  \
# 214       1         1                  Carter, Miss. Lucile Polk  female
# 245       1         1        Carter, Master. William Thornton II    male
# 746       1         1  Carter, Mrs. William Ernest (Lucile Polk)  female
#
#       age  sibsp  parch  ticket   fare    cabin embarked boat  body  \
# 214  14.0      1      2  113760  120.0  B96 B98        S    4   NaN
# 245  11.0      1      2  113760  120.0  B96 B98        S    4   NaN
# 746  36.0      1      2  113760  120.0  B96 B98        S    4   NaN
#
#          home.dest  fare>70
# 214  Bryn Mawr, PA     True
# 245  Bryn Mawr, PA     True
# 746  Bryn Mawr, PA     True

# %%
train_data[train_data["cabin"] == "B58 B60"]
# Out:
#      pclass  survived                                               name  \
# 121       1         0                           Baxter, Mr. Quigg Edmond
# 163       1         1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 266       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
#
#         sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# 121    male  24.0      0      1  PC 17558  247.5208  B58 B60        C  NaN
# 163  female  27.0      1      1  PC 17558  247.5208  B58 B60        C    6
# 266  female  50.0      0      1  PC 17558  247.5208  B58 B60        C    6
#
#      body     home.dest  fare>70
# 121   NaN  Montreal, PQ     True
# 163   NaN  Montreal, PQ     True
# 266   NaN  Montreal, PQ     True

# %%
train_data[train_data["cabin"] == "C78"]
# Out:
#      pclass  survived                         name     sex   age  sibsp  \
# 66        1         1       Minahan, Miss. Daisy E  female  33.0      1
# 335       1         0  Minahan, Dr. William Edward    male  44.0      2
# 369       1         1     Mock, Mr. Philipp Edmund    male  30.0      1
#
#      parch ticket   fare cabin embarked boat   body        home.dest  fare>70
# 66       0  19928  90.00   C78        Q   14    NaN    Green Bay, WI     True
# 335      0  19928  90.00   C78        Q  NaN  230.0  Fond du Lac, WI     True
# 369      0  13236  57.75   C78        C   11    NaN     New York, NY    False

# %% [markdown]
# Seems like the higher the cabin value counts correlates to the the chance of survival.

# %%
cabin_alone = list(train_data["cabin"].value_counts()[train_data["cabin"].value_counts() == 1].index)
cabin_not_alone = list(train_data["cabin"].value_counts()[train_data["cabin"].value_counts() != 1].index)

cabin_alone_data = train_data[train_data["cabin"].isin(cabin_alone)]
cabin_not_alone_data = train_data[train_data["cabin"].isin(cabin_not_alone)]
cabin_missing_data = train_data[train_data["cabin"].isna()]

# %%
cabin_alone_data["survived"].value_counts() / cabin_alone_data.shape[0]
# Out:
# 1    0.605769
# 0    0.394231
# Name: survived, dtype: float64

# %%
cabin_not_alone_data["survived"].value_counts() / cabin_not_alone_data.shape[0]
# Out:
# 1    0.811765
# 0    0.188235
# Name: survived, dtype: float64

# %%
cabin_missing_data["survived"].value_counts() / cabin_missing_data.shape[0]
# Out:
# 0    0.682336
# 1    0.317664
# Name: survived, dtype: float64

# %% [markdown]
# Let $\mathbb{B}:=\{0,1\}$. We decided to represent cabin column as one hot in $\mathbb{B}^{2}$:
#
# * $[0,0]$ for missing value
# * $[1,0]$ for not alone (has value counts > 1)
# * $[0,1]$ for alone (value counts == 1)

# %% [markdown]
# ### Embarked

# %%
train_data["embarked"].value_counts()
# Out:
# S    632
# C    186
# Q     72
# Name: embarked, dtype: int64

# %% [markdown]
# We will be representing embarked column as one hot

# %% [markdown]
# ### Home.dest

# %%
train_data["home.dest"].value_counts()
# Out:
# New York, NY                            41
# London                                  11
# Wiltshire, England Niagara Falls, NY     7
# Montreal, PQ                             7
# Paris, France                            7
#                                         ..
# Brookline, MA                            1
# Tofta, Sweden Joliet, IL                 1
# Stockholm, Sweden New York               1
# Altdorf, Switzerland                     1
# Vancouver, BC                            1
# Name: home.dest, Length: 280, dtype: int64

# %% [markdown]
# We assume that the home.dest is not beneficial for our prediction, so we decided not to include it.
